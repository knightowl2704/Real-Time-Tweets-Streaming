# %%
import credentials
import settings

# %%
import re
import tweepy
import mysql.connector
import pandas as pd
from textblob import TextBlob

# %%
class MyStreamListener(tweepy.StreamListener):
    def on_status(self, status):
        if status.retweeted:
            return True
        
        id_str = status.id_str
        created_at = status.created_at
        text = deEmojify(status.text)  
        sentiment = TextBlob(text).sentiment
        polarity = sentiment.polarity
        subjectivity = sentiment.subjectivity
        
        user_created_at = status.user.created_at
        user_location = deEmojify(status.user.location)
        user_description = deEmojify(status.user.description)
        user_followers_count =status.user.followers_count
        longitude = None
        latitude = None
        if status.coordinates:
            longitude = status.coordinates['coordinates'][0]
            latitude = status.coordinates['coordinates'][1]
            
        retweet_count = status.retweet_count
        favorite_count = status.favorite_count
        
        print(status.text)
        print("Long: {}, Lati: {}".format(longitude, latitude))
        
        if mydb.is_connected():
            mycursor = mydb.cursor()
            sql = "INSERT INTO {} (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)".format(settings.TABLE_NAME)
            val = (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, \
                user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count)
            mycursor.execute(sql, val)
            mydb.commit()
            mycursor.close()
    
    def on_error(self, status_code):
        if status_code == 420:
            # return False to disconnect the stream
            return False

# %%
    def clean_tweets(self,tweet):
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) \
                                |(\w+:\/\/\S+)", " ", tweet).split()) 
    def deEmojify(text):
        if text:
            return text.encode('ascii', 'ignore').decode('ascii')
        else:
            return None

# %%
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="piyush27",
    database="twitterdb",
    charset = 'utf8'
)

# %%
if mydb.is_connected():
    mycursor = mydb.cursor()
    mycursor.execute("""
        SELECT COUNT(*)
        FROM information_schema.tables
        WHERE table_name = '{0}'
        """.format(settings.TABLE_NAME))
    if mycursor.fetchone()[0] != 1:
        mycursor.execute("CREATE TABLE {} ({})".format(settings.TABLE_NAME, settings.TABLE_ATTRIBUTES))
        mydb.commit()
    mycursor.close()

# %%
auth  = tweepy.OAuthHandler(credentials.API_KEY, credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
myStream.filter(languages=["en"], track = settings.TRACK_WORDS)
# Close the MySQL connection as it finished
# However, this won't be reached as the stream listener won't stop automatically
# Press STOP button to finish the process.
mydb.close()
# Out:
# Wash your hands! Also, advocate for better sick day provisions so workers can afford to stay home when they’re ill.… https://t.co/nOFr3DVanV
# Long: None, Lati: None
# Good news guys...Our How to guide to run Facebook and Instagram ad is ready....We are selling at 4000 only...All yo… https://t.co/1upj0knfM9
# Long: None, Lati: None
# RT @BTSfansite: @bts_bighit [OFFICIAL] 200304 BTS Facebook Update: In Commemoration of 'ON' Billboard Hot 100 4th Place - BTS emoticON - #J…
# Long: None, Lati: None
# RT @ckarr2: @PaulWBNG Koda has been FOUND!!!  He will be reunited with his family today.  Here's the photo from the family who found and ke…
# Long: None, Lati: None
# RT @NatashaBertrand: Wild story from @ChristopherJM &gt;&gt;&gt; a Ukrainian lawmaker "published on Facebook, where he has 145,000 followers, and on…
# Long: None, Lati: None
# Hey @Facebook / @oculus employees - check out this guy’s timeline defending you/attacking me.
#
# The longer you stay… https://t.co/iYkbyup26z
# Long: None, Lati: None
# I pledge $20.
# Who's going to join me?
# PLEDGE
# RESCUE
# FOSTER
# Long: None, Lati: None
# RT @VoteBlue_2020_: @realDonaldTrump Thanks to #bloomberg2020, his ads reached the News, Twitter, Facebook, TV Stations, the Superbowl and…
# Long: None, Lati: None
# RT @seanmdav: If only Bloomberg had hired Russians to buy $100,000 in barely literate Facebook ads, instead of spending $700 MILLION, he’d…
# Long: None, Lati: None
# RT @NotTodayEric: Twitter is proof that everyone on facebook is faking it.
# Long: None, Lati: None
# RT @NYCDEATHROWCATS: ***TO BE DESTROYED 03/05/20*** **RETURN**
#
# MARVELOUS MISU IS STRESSED IN THE SHELTER AND NEEDS A HERO TONIGHT!. Misu w…
# Long: None, Lati: None
# RT @hello82official: 😎Welcome to 82Challenge!😎
# Starring ATEEZ! Tuesdays at 6PM PST.🇺🇸
# Starting on March 10, join us for 8 exciting episodes…
# Long: None, Lati: None
# Bogus child abuse campaigner Jon Wedger
# "I'm in Norfolk, I'm on my way to an RAF base to give a talk to the officer… https://t.co/EDtDs7iUrj
# Long: None, Lati: None
# RT @seanmdav: If only Bloomberg had hired Russians to buy $100,000 in barely literate Facebook ads, instead of spending $700 MILLION, he’d…
# Long: None, Lati: None
# RT @DonaldJTrumpJr: Solid point.
# Long: None, Lati: None
# RT @doyou_bangtan: To celebrate 4th place on Billboard Hot 100!
# BTS has prepared this for ARMY in their thankfulness!
#
# BTS emoticON
# ☆★Bang.…
# Long: None, Lati: None
# What improvements would you like to see along the #NeponsetGreenway trail? What should the Greenway Council focus o… https://t.co/95WshG0Thp
# Long: None, Lati: None
# Are we supposed to be shocked?
#
# The Democrat machine aligns behind @JoeBiden. #kag #maga
#
# https://t.co/eTX29A1CFB
# Long: None, Lati: None
# RT @GAM_Morris: What happens  when the powers up above decided to create the soul of the Goddess of Justice, and send it to Earth to delive…
# Long: None, Lati: None
# RT @bts_bighit: #BTS #방탄소년단 ‘ON’ Official MV Photo Sketch @ (https://t.co/SNwRuWtDD7) https://t.co/hSb0SkeHyW
# Long: None, Lati: None
# RT @seanmdav: If only Bloomberg had hired Russians to buy $100,000 in barely literate Facebook ads, instead of spending $700 MILLION, he’d…
# Long: None, Lati: None
# Great pup up for adoption!
# Long: None, Lati: None
# @MonerahChita @DerekPa56710094 @19marino74 @meritaeneg @Rose_Ilda_bem @Alexa17101614 @Jimmysimmonds1 @Wewillrocku66… https://t.co/BRIz9tasQu
# Long: None, Lati: None
# RT @Tamuna610: Those who are interested in my stories can follow me on fb page: https://t.co/6cLzhBXbLe ^_^ https://t.co/fXYGjJJe3m
# Long: None, Lati: None
# RT @NYCDEATHROWCATS: *** TO BE DESTROYED 03/05/20 ***
#
# SECOND CHANCE FOR LANDO TONIGHT!!
#
# LANDO NEEDS RESCUE PARTNER!! https://t.co/36EAfpm…
# Long: None, Lati: None
# RT @anneapplebaum: Facebook's "fact-checking" system does not work. This thread is Exhibit A
# Long: None, Lati: None
# RT @DonaldJTrumpJr: Solid point. https://t.co/DGmamgwviv
# Long: None, Lati: None
# @kyletwebster IG, Twitter.
# I did try Facebook but literally no one saw my posts unless I paid up. IG is a hit and… https://t.co/8KPamiIoow
# Long: None, Lati: None
# NO WONDER LITERALLY ALL OF THESE HAD BLACK SWAN LYRICS ON THEM
# Long: None, Lati: None
# RT @PeterAskin1: Orion is a handsome #PhillyPA kitty with severe mobility issues &amp; needs some help for lifesaving surgery! Zoanne Campell i…
# Long: None, Lati: None
# RT @no1_nicola: I have kept rather quiet on the whole #covid19UK thing. But I saw this on facebook &amp; had to share it. As hard hitting as it…
# Long: None, Lati: None
# RT @kk_in_AB: You should thank them for doing your job @CBCNews
#
# How about report on the anti-canadian oil campaign funded by foreign money…
# Long: None, Lati: None
# RT @SIUSalukis: 1 vision. 24 hours. Follow along with the @SIUSalukis Development team on our Facebook story as they take you behind the sc…
# Long: None, Lati: None
# RT @AsunaLiiGaming: 10 more followers to hit 1k on FACEBOOK!
# Lets gooo 🔥🔥🔥
# If you guys could help me out for those follows. I will apprecia…
# Long: None, Lati: None
# It's TODAY! Head over to Inman News on Facebook to hear Angelica Olmsted from @remax share the wisdom of the projec… https://t.co/12sAuOMCFV
# Long: None, Lati: None
# Did you know that where you choose to study can have a significant impact on your learning ability and overall acad… https://t.co/DrjfLKlQDw
# Long: None, Lati: None
# RT @JayneMarie007: 🔥Critical Now 📢
#
# 🆘SOUTH #TEXAS SHELTER DOGS🆘
#
#  ‼️ NEEDS A HOLD BY 10PM #TONIGHT OR WILL BE KILLED 3/3/2020💉
#
#  📣 Pls Sha…
# Long: None, Lati: None
# @canestastic2020 @washingtonpost So Facebook has the ability to target Facebook ad based on knowing they are undeci… https://t.co/eCLHiWUVGf
# Long: None, Lati: None
# RT @Mytowntvhd: WATCH: @BSpicerTV takes you inside the 16th Region tournament as he talks with longtime MSU and Ashland PA announcer Chuck…
# Long: None, Lati: None
# RT @Sirajum13794010: @Hrithika_kk125 Fifafooz youtube-
#  https://t.co/4cxyzuPxQc
# Fifafooz youtube 2-
# https://t.co/sDZYksv31r
# Fifafooz facebo…
# Long: None, Lati: None
# When doesn't Trump contradict himself in the same sentence!?!
# Long: None, Lati: None
# #CITSUElections20 Watch today's hustings to help make up your mind https://t.co/y5mbVaJOhm
#  Use your vote #yourunionyourvoice
# Long: None, Lati: None
# I left FB months ago and don't miss a bit
# Long: None, Lati: None
# The Russians spent $100K on Facebook ads in 2016, which made the idiots think that Russia had determined the outcom… https://t.co/dtSQbrahAv
# Long: None, Lati: None
# RT @NYCDEATHROWCATS: Sylvester was dumped by his owner. This handsome tux needs a follow up vet check for dental issues.
# Sylvester is waiti…
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: #SarahGeronimo surpasses 100 million views on #YouTube with her viral smash hit #Tala, and becomes the 1st Philippine…
# Long: None, Lati: None
# RT @RusEmbUSA: #RussianHeritageNight is coming to New Jersey on March 10 as Nikita Gusev and the @NJDevils take on Evgeny Malkin and the @P…
# Long: None, Lati: None
# @leo1992s He has IG or Twitter or Facebook?
# Long: None, Lati: None
# Seriously tempted to make a fake Facebook profile so that I can send a message to the anonymous whistle-blower Face… https://t.co/dmG0rxlP4b
# Long: None, Lati: None
# RT @prabhu_sr: Feels light after speaking up the mind! 🤘🏼
#
#  https://t.co/hxUqMN2HAC
# Long: None, Lati: None
# Very good
# Long: None, Lati: None
# @cineworld Not really good enough! If you look on Facebook post many many people complaining!  Even recently! And y… https://t.co/oVjlGsgodg
# Long: None, Lati: None
# RT @DonaldJTrumpJr: Solid point.
# Long: None, Lati: None
# Facebook be hitting me with all the fun events that's coming up 😭
# Long: None, Lati: None
# RT @ZEEMAN_GROUP: Ladies 💃 30% OFF SALE is still on !! 🔥🔥
#
# ●With Free Delivery in S.A● 🚚 🇿🇦
#
# Shop Now : https://t.co/3PYqH5aeoo
#
# IG : https…
# Long: None, Lati: None
# RT @bobert9707: I need to stay the fuck off Facebook today oh my lord. The BOOMERS ARE OUT TODAY KAREN
# Long: None, Lati: None
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-ff56b86508dd> in <module>
#       1 myStreamListener = MyStreamListener()
#       2 myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
# ----> 3 myStream.filter(languages=["en"], track = settings.TRACK_WORDS)
#       4 # Close the MySQL connection as it finished
#       5 # However, this won't be reached as the stream listener won't stop automatically
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     589
#     590                 if len(mvb) <= chunk_left:
# --> 591                     n = self._safe_readinto(mvb)
#     592                     self.chunk_left = chunk_left - n
#     593                     return total_bytes + n
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _safe_readinto(self, b)
#     634                 n = self.fp.readinto(temp_mvb)
#     635             else:
# --> 636                 n = self.fp.readinto(mvb)
#     637             if not n:
#     638                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     310                 raise timeout('The read operation timed out')
#     311             else:
# --> 312                 return self.recv_into(*args, **kwargs)
#     313
#     314     def settimeout(self, timeout):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      81     # thing.)
#      82     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 83     rready, wready, xready = _retry_on_intr(fn, timeout)
#      84     return bool(rready or wready or xready)
#      85
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# KeyboardInterrupt:
